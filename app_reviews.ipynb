# %%
from google_play_scraper import reviews as google_reviews
from google_play_scraper import app, Sort, reviews_all
from app_store_scraper import AppStore
import numpy as np
import pandas as pd
import json, os, uuid
import matplotlib.pyplot as plt

# %%
# Lista de IDs de aplicativos para extrair reviews
app_ids = [
    'br.com.bradesco.netempresa',  
    'br.com.bradesco.pdpjapp',      
    'com.itau.empresas',
    'com.btg.business',
    'br.livetouch.safra.empresas'

]

# %%
def extracao_reviews_google_store(app_ids):
    all_reviews = []

    for app_id in app_ids:
        print(f'Extraindo reviews para o app: {app_id}')

        app_reviews = reviews_all(
            app_id,
            sleep_milliseconds=0, # defaults to 0
            lang='pt', # defaults to 'en'
            country='br', # defaults to 'us'
            sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
        )
        # Adicionar uma coluna indicando o aplicativo
        for review in app_reviews:
            review['app_id'] = app_id
            review["store"] = "Google Play"

        # Adicionar os reviews à lista total
        all_reviews.extend(app_reviews)
        
    return pd.DataFrame(all_reviews)

# %%
# Chamada da função para extrair reviews de todos os aplicativos
reviews_df = extracao_reviews_google_store(app_ids)
# Out:
# Extraindo reviews para o app: br.com.bradesco.netempresa
# Extraindo reviews para o app: br.com.bradesco.pdpjapp
# Extraindo reviews para o app: com.itau.empresas
# Extraindo reviews para o app: com.btg.business
# Extraindo reviews para o app: br.livetouch.safra.empresas

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107424 entries, 0 to 107423
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              107424 non-null  object
#  1   userName              107424 non-null  object
#  2   userImage             107424 non-null  object
#  3   content               107400 non-null  object
#  4   score                 107424 non-null  int64
#  5   thumbsUpCount         107424 non-null  int64
#  6   reviewCreatedVersion  96505 non-null   object
#  7   at                    107424 non-null  datetime64[ns]
#  8   replyContent          58583 non-null   object
#  9   repliedAt             58583 non-null   datetime64[ns]
#  10  appVersion            96505 non-null   object
#  11  app_id                107424 non-null  object
#  12  store                 107424 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(9)
# memory usage: 10.7+ MB

# %%
reviews_df
# Out:
#                                     reviewId              userName  \
# 0       48b3ce35-af94-473d-8dfe-b2c244925949  Um usuário do Google
# 1       12f6cc06-af33-428f-b8b7-743436aa4e19  Um usuário do Google
# 2       b14b5c41-920e-4dea-8447-a5d0bbf0207d  Um usuário do Google
# 3       95ab9345-73b9-46d8-937e-4f3f9b91dfde  Um usuário do Google
# 4       054a7cbd-7601-4b0a-ae62-c1e2591f6194  Um usuário do Google
# ...                                      ...                   ...
# 107873  ba1e9e9d-1a3e-4ba9-84fa-a50b31fd10f6  Um usuário do Google
# 107874  c569a97b-487f-4b7e-8d23-132642c11bd3  Um usuário do Google
# 107875  aa5b1e25-dceb-464c-9db4-947dcf3da7f3  Um usuário do Google
# 107876  34749b1e-a03b-4dea-8080-4d96a0e81732  Um usuário do Google
# 107877  321637de-77c6-4127-9d64-7345e7c6df39  Um usuário do Google
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/EGemoI2N...
# 1       https://play-lh.googleusercontent.com/EGemoI2N...
# 2       https://play-lh.googleusercontent.com/EGemoI2N...
# 3       https://play-lh.googleusercontent.com/EGemoI2N...
# 4       https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                   ...
# 107873  https://play-lh.googleusercontent.com/EGemoI2N...
# 107874  https://play-lh.googleusercontent.com/EGemoI2N...
# 107875  https://play-lh.googleusercontent.com/EGemoI2N...
# 107876  https://play-lh.googleusercontent.com/EGemoI2N...
# 107877  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 0       Da erro e fecha sozinho ,não puxa extrato só d...      1
# 1                                          Muito ótimoooo      5
# 2                                             Excelente 👏      5
# 3                             Facil de trabalhar com ele.      5
# 4       Nao funcionou. Pede a chave de seguranca que j...      1
# ...                                                   ...    ...
# 107873                      Ágil, moderno...muito prático      5
# 107874       Estava acessando normalmente, agora não abre      2
# 107875  Teve probleminha na migração do antigo para o ...      5
# 107876     O app novo ficou bonito e muito fácil de usar.      5
# 107877                                          Muito bom      5
#
#         thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0                   0                 None 2025-03-11 20:23:03         None
# 1                   0              5.44.02 2025-03-11 19:07:50         None
# 2                   0              5.44.02 2025-03-11 17:06:38         None
# 3                   0                 None 2025-03-11 16:26:26         None
# 4                   0              5.44.02 2025-03-11 12:40:39         None
# ...               ...                  ...                 ...          ...
# 107873              1                 1.11 2017-04-13 09:24:15         None
# 107874              0                 None 2017-01-25 10:23:57         None
# 107875              0                  1.9 2017-01-18 16:09:54         None
# 107876              1                  1.9 2017-01-12 16:28:19         None
# 107877              4                  1.1 2015-05-28 10:38:13         None
#
#        repliedAt appVersion                       app_id        store
# 0            NaT       None   br.com.bradesco.netempresa  Google Play
# 1            NaT    5.44.02   br.com.bradesco.netempresa  Google Play
# 2            NaT    5.44.02   br.com.bradesco.netempresa  Google Play
# 3            NaT       None   br.com.bradesco.netempresa  Google Play
# 4            NaT    5.44.02   br.com.bradesco.netempresa  Google Play
# ...          ...        ...                          ...          ...
# 107873       NaT       1.11  br.livetouch.safra.empresas  Google Play
# 107874       NaT       None  br.livetouch.safra.empresas  Google Play
# 107875       NaT        1.9  br.livetouch.safra.empresas  Google Play
# 107876       NaT        1.9  br.livetouch.safra.empresas  Google Play
# 107877       NaT        1.1  br.livetouch.safra.empresas  Google Play
#
# [107878 rows x 13 columns]

# %%
df_reviews_google = reviews_df

# %%
df_reviews_google = df_reviews_google.rename(columns={
    "userName": "user",        
    "content": "review",       
    "score": "score",  
    "replyContent":"resposta",
    "at": "data",               
    "app_id":"app_name"
})

# %%
df_reviews_google
# Out:
#                                     reviewId                  user  \
# 0       48b3ce35-af94-473d-8dfe-b2c244925949  Um usuário do Google
# 1       12f6cc06-af33-428f-b8b7-743436aa4e19  Um usuário do Google
# 2       b14b5c41-920e-4dea-8447-a5d0bbf0207d  Um usuário do Google
# 3       95ab9345-73b9-46d8-937e-4f3f9b91dfde  Um usuário do Google
# 4       054a7cbd-7601-4b0a-ae62-c1e2591f6194  Um usuário do Google
# ...                                      ...                   ...
# 107873  ba1e9e9d-1a3e-4ba9-84fa-a50b31fd10f6  Um usuário do Google
# 107874  c569a97b-487f-4b7e-8d23-132642c11bd3  Um usuário do Google
# 107875  aa5b1e25-dceb-464c-9db4-947dcf3da7f3  Um usuário do Google
# 107876  34749b1e-a03b-4dea-8080-4d96a0e81732  Um usuário do Google
# 107877  321637de-77c6-4127-9d64-7345e7c6df39  Um usuário do Google
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/EGemoI2N...
# 1       https://play-lh.googleusercontent.com/EGemoI2N...
# 2       https://play-lh.googleusercontent.com/EGemoI2N...
# 3       https://play-lh.googleusercontent.com/EGemoI2N...
# 4       https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                   ...
# 107873  https://play-lh.googleusercontent.com/EGemoI2N...
# 107874  https://play-lh.googleusercontent.com/EGemoI2N...
# 107875  https://play-lh.googleusercontent.com/EGemoI2N...
# 107876  https://play-lh.googleusercontent.com/EGemoI2N...
# 107877  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                    review  score  \
# 0       Da erro e fecha sozinho ,não puxa extrato só d...      1
# 1                                          Muito ótimoooo      5
# 2                                             Excelente 👏      5
# 3                             Facil de trabalhar com ele.      5
# 4       Nao funcionou. Pede a chave de seguranca que j...      1
# ...                                                   ...    ...
# 107873                      Ágil, moderno...muito prático      5
# 107874       Estava acessando normalmente, agora não abre      2
# 107875  Teve probleminha na migração do antigo para o ...      5
# 107876     O app novo ficou bonito e muito fácil de usar.      5
# 107877                                          Muito bom      5
#
#         thumbsUpCount reviewCreatedVersion                data resposta  \
# 0                   0                 None 2025-03-11 20:23:03     None
# 1                   0              5.44.02 2025-03-11 19:07:50     None
# 2                   0              5.44.02 2025-03-11 17:06:38     None
# 3                   0                 None 2025-03-11 16:26:26     None
# 4                   0              5.44.02 2025-03-11 12:40:39     None
# ...               ...                  ...                 ...      ...
# 107873              1                 1.11 2017-04-13 09:24:15     None
# 107874              0                 None 2017-01-25 10:23:57     None
# 107875              0                  1.9 2017-01-18 16:09:54     None
# 107876              1                  1.9 2017-01-12 16:28:19     None
# 107877              4                  1.1 2015-05-28 10:38:13     None
#
#        repliedAt appVersion                     app_name        store
# 0            NaT       None   br.com.bradesco.netempresa  Google Play
# 1            NaT    5.44.02   br.com.bradesco.netempresa  Google Play
# 2            NaT    5.44.02   br.com.bradesco.netempresa  Google Play
# 3            NaT       None   br.com.bradesco.netempresa  Google Play
# 4            NaT    5.44.02   br.com.bradesco.netempresa  Google Play
# ...          ...        ...                          ...          ...
# 107873       NaT       1.11  br.livetouch.safra.empresas  Google Play
# 107874       NaT       None  br.livetouch.safra.empresas  Google Play
# 107875       NaT        1.9  br.livetouch.safra.empresas  Google Play
# 107876       NaT        1.9  br.livetouch.safra.empresas  Google Play
# 107877       NaT        1.1  br.livetouch.safra.empresas  Google Play
#
# [107878 rows x 13 columns]

# %%
# Selecionando colunas comuns para unificação
common_columns = ["user", "review", "score",'resposta', "data", "app_name", "store"]

# %%
df_reviews_google_final = df_reviews_google[common_columns]

# %%
df_reviews_google_final
# Out:
#                         user  \
# 0       Um usuário do Google
# 1       Um usuário do Google
# 2       Um usuário do Google
# 3       Um usuário do Google
# 4       Um usuário do Google
# ...                      ...
# 107873  Um usuário do Google
# 107874  Um usuário do Google
# 107875  Um usuário do Google
# 107876  Um usuário do Google
# 107877  Um usuário do Google
#
#                                                    review  score resposta  \
# 0       Da erro e fecha sozinho ,não puxa extrato só d...      1     None
# 1                                          Muito ótimoooo      5     None
# 2                                             Excelente 👏      5     None
# 3                             Facil de trabalhar com ele.      5     None
# 4       Nao funcionou. Pede a chave de seguranca que j...      1     None
# ...                                                   ...    ...      ...
# 107873                      Ágil, moderno...muito prático      5     None
# 107874       Estava acessando normalmente, agora não abre      2     None
# 107875  Teve probleminha na migração do antigo para o ...      5     None
# 107876     O app novo ficou bonito e muito fácil de usar.      5     None
# 107877                                          Muito bom      5     None
#
#                       data                     app_name        store
# 0      2025-03-11 20:23:03   br.com.bradesco.netempresa  Google Play
# 1      2025-03-11 19:07:50   br.com.bradesco.netempresa  Google Play
# 2      2025-03-11 17:06:38   br.com.bradesco.netempresa  Google Play
# 3      2025-03-11 16:26:26   br.com.bradesco.netempresa  Google Play
# 4      2025-03-11 12:40:39   br.com.bradesco.netempresa  Google Play
# ...                    ...                          ...          ...
# 107873 2017-04-13 09:24:15  br.livetouch.safra.empresas  Google Play
# 107874 2017-01-25 10:23:57  br.livetouch.safra.empresas  Google Play
# 107875 2017-01-18 16:09:54  br.livetouch.safra.empresas  Google Play
# 107876 2017-01-12 16:28:19  br.livetouch.safra.empresas  Google Play
# 107877 2015-05-28 10:38:13  br.livetouch.safra.empresas  Google Play
#
# [107878 rows x 7 columns]

# %% [markdown]
# ### Extração Reviews Apple store

# %% [markdown]
# # Apple id
# https://apps.apple.com/br/app/bradesco-net-empresa/id462977200
# https://apps.apple.com/br/app/ita%C3%BA-empresas-conta-pj/id348274534
# https://apps.apple.com/br/app/btg-pactual-empresas-conta-pj/id1501414115
# https://apps.apple.com/br/app/safra-empresas-a-sua-conta-pj/id417297468
#
#     apple_apps = {
#     "Bradesco Net Empresa": 462977200,
#     "Itaú Empresas": 348274534,
#     "BTG Pactual Empresas": 1501414115,
#     "Safra Empresas": 417297468
# }
#
#
# # apple_reviews = AppStore(
# #                 country="br",
# #                 app_name="bradesco-net-empresa", app_id=462977200)

# %%
apple_reviews.review()

# %%
apple_apps = {
    "Bradesco Net Empresa": 462977200,
    "Itaú Empresas": 348274534,
    "BTG Pactual Empresas": 1501414115,
    "Safra Empresas": 417297468
}

# Lista para armazenar os reviews de todos os apps
all_reviews = []

# Iterar sobre os aplicativos e coletar reviews
for app_name, app_id in apple_apps.items():
    print(f"Extraindo reviews para: {app_name}...")
    
    app = AppStore(country="br", app_name=app_name, app_id=app_id)
    app.review(how_many=5000)  # Tenta coletar o máximo de reviews disponíveis

    # Criar um DataFrame para cada app
    df = pd.DataFrame(app.reviews)
    df["app_name"] = app_name  # Adicionar a coluna do nome do app
    df["store"] = "Apple Store"

    # Adicionar ao conjunto geral
    all_reviews.append(df)

# Concatenar todos os reviews em um único DataFrame
reviews_df_apple = pd.concat(all_reviews, ignore_index=True)
# Out:
# Extraindo reviews para: Bradesco Net Empresa...
# 2025-03-12 21:21:28,207 [INFO] Base - Initialised: AppStore('br', 'bradesco-net-empresa', 462977200)
# 2025-03-12 21:21:28,207 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/br/app/bradesco-net-empresa/id462977200
# 2025-03-12 21:21:33,811 [INFO] Base - [id:462977200] Fetched 180 reviews (180 fetched in total)
# 2025-03-12 21:21:39,718 [INFO] Base - [id:462977200] Fetched 380 reviews (380 fetched in total)
# 2025-03-12 21:21:45,685 [INFO] Base - [id:462977200] Fetched 560 reviews (560 fetched in total)
# 2025-03-12 21:21:51,765 [INFO] Base - [id:462977200] Fetched 760 reviews (760 fetched in total)
# 2025-03-12 21:21:57,960 [INFO] Base - [id:462977200] Fetched 940 reviews (940 fetched in total)
# 2025-03-12 21:22:04,070 [INFO] Base - [id:462977200] Fetched 1120 reviews (1120 fetched in total)
# 2025-03-12 21:22:04,449 [WARNING] urllib3.connectionpool - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'Foi forçado o cancelamento de uma conexão existente pelo host remoto', None, 10054, None))': /v1/catalog/br/apps/462977200/reviews?l=en-GB&offset=1120&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac
# 2025-03-12 21:22:10,185 [INFO] Base - [id:462977200] Fetched 1300 reviews (1300 fetched in total)
# 2025-03-12 21:22:16,028 [INFO] Base - [id:462977200] Fetched 1480 reviews (1480 fetched in total)
# 2025-03-12 21:22:22,149 [INFO] Base - [id:462977200] Fetched 1680 reviews (1680 fetched in total)
# 2025-03-12 21:22:23,097 [WARNING] urllib3.connectionpool - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'Foi forçado o cancelamento de uma conexão existente pelo host remoto', None, 10054, None))': /v1/catalog/br/apps/462977200/reviews?l=en-GB&offset=1700&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac
# 2025-03-12 21:22:28,256 [INFO] Base - [id:462977200] Fetched 1860 reviews (1860 fetched in total)
# 2025-03-12 21:22:34,430 [INFO] Base - [id:462977200] Fetched 2060 reviews (2060 fetched in total)
# 2025-03-12 21:22:40,422 [INFO] Base - [id:462977200] Fetched 2220 reviews (2220 fetched in total)
# 2025-03-12 21:22:46,549 [INFO] Base - [id:462977200] Fetched 2400 reviews (2400 fetched in total)
# 2025-03-12 21:22:52,695 [INFO] Base - [id:462977200] Fetched 2600 reviews (2600 fetched in total)
# 2025-03-12 21:22:58,820 [INFO] Base - [id:462977200] Fetched 2780 reviews (2780 fetched in total)
# 2025-03-12 21:23:04,900 [INFO] Base - [id:462977200] Fetched 2960 reviews (2960 fetched in total)
# 2025-03-12 21:23:05,267 [WARNING] urllib3.connectionpool - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'Foi forçado o cancelamento de uma conexão existente pelo host remoto', None, 10054, None))': /v1/catalog/br/apps/462977200/reviews?l=en-GB&offset=2960&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac
# 2025-03-12 21:23:11,083 [INFO] Base - [id:462977200] Fetched 3140 reviews (3140 fetched in total)
# 2025-03-12 21:23:16,717 [INFO] Base - [id:462977200] Fetched 3320 reviews (3320 fetched in total)
# 2025-03-12 21:23:22,951 [INFO] Base - [id:462977200] Fetched 3520 reviews (3520 fetched in total)
# 2025-03-12 21:23:28,788 [INFO] Base - [id:462977200] Fetched 3700 reviews (3700 fetched in total)
# 2025-03-12 21:23:34,916 [INFO] Base - [id:462977200] Fetched 3880 reviews (3880 fetched in total)
# 2025-03-12 21:23:41,180 [INFO] Base - [id:462977200] Fetched 4060 reviews (4060 fetched in total)
# 2025-03-12 21:23:47,982 [INFO] Base - [id:462977200] Fetched 4220 reviews (4220 fetched in total)
# Extraindo reviews para: Itaú Empresas...
# 2025-03-12 21:23:49,780 [INFO] Base - Initialised: AppStore('br', 'itaú-empresas', 348274534)
# 2025-03-12 21:23:49,781 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/br/app/itaú-empresas/id348274534
# 2025-03-12 21:23:54,860 [INFO] Base - [id:348274534] Fetched 160 reviews (160 fetched in total)
# 2025-03-12 21:24:00,638 [INFO] Base - [id:348274534] Fetched 340 reviews (340 fetched in total)
# 2025-03-12 21:24:06,843 [INFO] Base - [id:348274534] Fetched 520 reviews (520 fetched in total)
# 2025-03-12 21:24:12,991 [INFO] Base - [id:348274534] Fetched 720 reviews (720 fetched in total)
# 2025-03-12 21:24:18,617 [INFO] Base - [id:348274534] Fetched 880 reviews (880 fetched in total)
# 2025-03-12 21:24:22,512 [WARNING] urllib3.connectionpool - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'Foi forçado o cancelamento de uma conexão existente pelo host remoto', None, 10054, None))': /v1/catalog/br/apps/348274534/reviews?l=en-GB&offset=1000&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac
# 2025-03-12 21:24:24,354 [INFO] Base - [id:348274534] Fetched 1060 reviews (1060 fetched in total)
# 2025-03-12 21:24:30,226 [INFO] Base - [id:348274534] Fetched 1240 reviews (1240 fetched in total)
# 2025-03-12 21:24:33,360 [WARNING] urllib3.connectionpool - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'Foi forçado o cancelamento de uma conexão existente pelo host remoto', None, 10054, None))': /v1/catalog/br/apps/348274534/reviews?l=en-GB&offset=1320&limit=20&platform=web&additionalPlatforms=appletv%2Cipad%2Ciphone%2Cmac
# 2025-03-12 21:24:35,994 [INFO] Base - [id:348274534] Fetched 1400 reviews (1400 fetched in total)
# 2025-03-12 21:24:41,733 [INFO] Base - [id:348274534] Fetched 1580 reviews (1580 fetched in total)
# 2025-03-12 21:24:47,717 [INFO] Base - [id:348274534] Fetched 1740 reviews (1740 fetched in total)
# 2025-03-12 21:24:53,965 [INFO] Base - [id:348274534] Fetched 1940 reviews (1940 fetched in total)
# 2025-03-12 21:24:59,690 [INFO] Base - [id:348274534] Fetched 2140 reviews (2140 fetched in total)
# 2025-03-12 21:25:05,356 [INFO] Base - [id:348274534] Fetched 2340 reviews (2340 fetched in total)
# 2025-03-12 21:25:11,264 [INFO] Base - [id:348274534] Fetched 2520 reviews (2520 fetched in total)
# 2025-03-12 21:25:17,178 [INFO] Base - [id:348274534] Fetched 2720 reviews (2720 fetched in total)
# 2025-03-12 21:25:23,031 [INFO] Base - [id:348274534] Fetched 2900 reviews (2900 fetched in total)
# 2025-03-12 21:25:29,031 [INFO] Base - [id:348274534] Fetched 3080 reviews (3080 fetched in total)
# 2025-03-12 21:25:34,882 [INFO] Base - [id:348274534] Fetched 3260 reviews (3260 fetched in total)
# 2025-03-12 21:25:40,666 [INFO] Base - [id:348274534] Fetched 3440 reviews (3440 fetched in total)
# 2025-03-12 21:25:46,646 [INFO] Base - [id:348274534] Fetched 3620 reviews (3620 fetched in total)
# 2025-03-12 21:25:52,753 [INFO] Base - [id:348274534] Fetched 3800 reviews (3800 fetched in total)
# 2025-03-12 21:25:58,450 [INFO] Base - [id:348274534] Fetched 3980 reviews (3980 fetched in total)
# 2025-03-12 21:26:04,737 [INFO] Base - [id:348274534] Fetched 4180 reviews (4180 fetched in total)
# 2025-03-12 21:26:10,966 [INFO] Base - [id:348274534] Fetched 4360 reviews (4360 fetched in total)
# 2025-03-12 21:26:16,559 [INFO] Base - [id:348274534] Fetched 4540 reviews (4540 fetched in total)
# 2025-03-12 21:26:22,295 [INFO] Base - [id:348274534] Fetched 4720 reviews (4720 fetched in total)
# 2025-03-12 21:26:28,421 [INFO] Base - [id:348274534] Fetched 4900 reviews (4900 fetched in total)
# 2025-03-12 21:26:32,135 [INFO] Base - [id:348274534] Fetched 5000 reviews (5000 fetched in total)
# Extraindo reviews para: BTG Pactual Empresas...
# 2025-03-12 21:26:34,064 [INFO] Base - Initialised: AppStore('br', 'btg-pactual-empresas', 1501414115)
# 2025-03-12 21:26:34,065 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/br/app/btg-pactual-empresas/id1501414115
# 2025-03-12 21:26:37,551 [INFO] Base - [id:1501414115] Fetched 106 reviews (106 fetched in total)
# Extraindo reviews para: Safra Empresas...
# 2025-03-12 21:26:39,169 [INFO] Base - Initialised: AppStore('br', 'safra-empresas', 417297468)
# 2025-03-12 21:26:39,170 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/br/app/safra-empresas/id417297468
# 2025-03-12 21:26:44,883 [INFO] Base - [id:417297468] Fetched 180 reviews (180 fetched in total)
# 2025-03-12 21:26:50,725 [INFO] Base - [id:417297468] Fetched 360 reviews (360 fetched in total)
# 2025-03-12 21:26:56,482 [INFO] Base - [id:417297468] Fetched 500 reviews (500 fetched in total)
# 2025-03-12 21:27:02,428 [INFO] Base - [id:417297468] Fetched 700 reviews (700 fetched in total)
# 2025-03-12 21:27:05,530 [INFO] Base - [id:417297468] Fetched 795 reviews (795 fetched in total)

# %%
reviews_df_apple
# Out:
#                      date                                  developerResponse  \
# 0     2020-03-13 22:08:36  {'id': 14124568, 'body': 'Boa tarde! O que est...
# 1     2020-11-16 12:03:34  {'id': 19246629, 'body': 'Bom dia! Gostaríamos...
# 2     2020-11-18 11:52:15  {'id': 19247464, 'body': 'Bom dia! Por gentile...
# 3     2020-03-14 00:25:42  {'id': 14124575, 'body': 'Boa tarde! Estamos t...
# 4     2019-03-14 20:09:39  {'id': 7755905, 'body': 'Boa tarde, Giovanni! ...
# ...                   ...                                                ...
# 10116 2018-07-04 17:05:03  {'id': 9619333, 'body': 'Oi, Raul. Você conseg...
# 10117 2025-03-10 21:58:29                                                NaN
# 10118 2012-05-26 16:45:17  {'id': 9619247, 'body': 'Olá. Disponibilizamos...
# 10119 2018-10-26 15:03:49  {'id': 9619398, 'body': 'Oi, Edu. Disponibiliz...
# 10120 2013-07-24 09:56:50  {'id': 9619254, 'body': 'Oi, Ed. Disponibiliza...
#
#                                                   review  rating  isEdited  \
# 0      Quiseram melhorar e estragaram e complicaram a...       5     False
# 1      Faz mais de 15 dias que o app esta entrando ap...       5     False
# 2      Está sempre “carregando” muitas vezes não efet...       1     False
# 3      Após atualização o APP não está abrindo no iPh...       1     False
# 4      está dando mensagem dizendo que horário do cel...       1     False
# ...                                                  ...     ...       ...
# 10116  Cadastrei a senha eletrônica com 6 dígitos. Ag...       1     False
# 10117  App “ok”, muitos bugs e plataforma pouco intui...       3     False
# 10118  Não funciona com 3g, só wifi. E não permite au...       1     False
# 10119                              Precisa melhorar tudo       1     False
# 10120  Após a ultima atualização o aplicativo nao ent...       1     False
#
#                                title            userName  \
# 0      Falha no App após atualização         cmte.malves
# 1                       Não funciona        xandezerbato
# 2                         Muito ruim  habilitar exterior
# 3             O app não está abrindo             Kilmeer
# 4                               Erro        GiovanniPolo
# ...                              ...                 ...
# 10116                   Não funciona             RaRaull
# 10117                    Modernidade        Alan Moreira
# 10118                          Fraco             Rtunoda
# 10119                Pessimooooooooo              Edu.05
# 10120      Nao funciona -TELA BRANCA           Ed_Alemao
#
#                    app_name        store
# 0      Bradesco Net Empresa  Apple Store
# 1      Bradesco Net Empresa  Apple Store
# 2      Bradesco Net Empresa  Apple Store
# 3      Bradesco Net Empresa  Apple Store
# 4      Bradesco Net Empresa  Apple Store
# ...                     ...          ...
# 10116        Safra Empresas  Apple Store
# 10117        Safra Empresas  Apple Store
# 10118        Safra Empresas  Apple Store
# 10119        Safra Empresas  Apple Store
# 10120        Safra Empresas  Apple Store
#
# [10121 rows x 9 columns]

# %%
reviews_df_apple["content"] = reviews_df_apple["developerResponse"].apply(lambda x: x.get("body") if isinstance(x, dict) else x)

# %%
df_reviews_apple = reviews_df_apple

# %%
# Renomeando colunas para padronizar
df_reviews_apple = df_reviews_apple.rename(columns={
    "userName": "user",         # Nome do usuário na Apple Store       # Review na Apple Store
    "rating": "score",          # Nota na Apple Store
    "date": "data",
    "content":'resposta'
})

# %%
df_reviews_apple = df_reviews_apple.drop('developerResponse', axis=1)

# %%
df_reviews_apple["store"] = "Apple Store"

# %%
df_reviews_apple
# Out:
#                      data                                             review  \
# 0     2020-03-13 22:08:36  Quiseram melhorar e estragaram e complicaram a...
# 1     2020-11-16 12:03:34  Faz mais de 15 dias que o app esta entrando ap...
# 2     2020-11-18 11:52:15  Está sempre “carregando” muitas vezes não efet...
# 3     2020-03-14 00:25:42  Após atualização o APP não está abrindo no iPh...
# 4     2019-03-14 20:09:39  está dando mensagem dizendo que horário do cel...
# ...                   ...                                                ...
# 10116 2018-07-04 17:05:03  Cadastrei a senha eletrônica com 6 dígitos. Ag...
# 10117 2025-03-10 21:58:29  App “ok”, muitos bugs e plataforma pouco intui...
# 10118 2012-05-26 16:45:17  Não funciona com 3g, só wifi. E não permite au...
# 10119 2018-10-26 15:03:49                              Precisa melhorar tudo
# 10120 2013-07-24 09:56:50  Após a ultima atualização o aplicativo nao ent...
#
#        score  isEdited                          title                user  \
# 0          5     False  Falha no App após atualização         cmte.malves
# 1          5     False                   Não funciona        xandezerbato
# 2          1     False                     Muito ruim  habilitar exterior
# 3          1     False         O app não está abrindo             Kilmeer
# 4          1     False                           Erro        GiovanniPolo
# ...      ...       ...                            ...                 ...
# 10116      1     False                   Não funciona             RaRaull
# 10117      3     False                    Modernidade        Alan Moreira
# 10118      1     False                          Fraco             Rtunoda
# 10119      1     False                Pessimooooooooo              Edu.05
# 10120      1     False      Nao funciona -TELA BRANCA           Ed_Alemao
#
#                    app_name        store  \
# 0      Bradesco Net Empresa  Apple Store
# 1      Bradesco Net Empresa  Apple Store
# 2      Bradesco Net Empresa  Apple Store
# 3      Bradesco Net Empresa  Apple Store
# 4      Bradesco Net Empresa  Apple Store
# ...                     ...          ...
# 10116        Safra Empresas  Apple Store
# 10117        Safra Empresas  Apple Store
# 10118        Safra Empresas  Apple Store
# 10119        Safra Empresas  Apple Store
# 10120        Safra Empresas  Apple Store
#
#                                                 resposta
# 0      Boa tarde! O que está acontecendo? Por gentile...
# 1      Bom dia! Gostaríamos de analisar essa situação...
# 2      Bom dia! Por gentileza, envie mais informações...
# 3      Boa tarde! Estamos trabalhando para que os dev...
# 4      Boa tarde, Giovanni! Vamos verificar o que est...
# ...                                                  ...
# 10116  Oi, Raul. Você conseguiu atualizar a senha e u...
# 10117                                                NaN
# 10118  Olá. Disponibilizamos uma atualização do aplic...
# 10119  Oi, Edu. Disponibilizamos uma atualização do a...
# 10120  Oi, Ed. Disponibilizamos uma atualização do ap...
#
# [10121 rows x 9 columns]

# %%
df_reviews_apple_final = df_reviews_apple[common_columns]
df_reviews_apple_final
# Out:
#                      user                                             review  \
# 0             cmte.malves  Quiseram melhorar e estragaram e complicaram a...
# 1            xandezerbato  Faz mais de 15 dias que o app esta entrando ap...
# 2      habilitar exterior  Está sempre “carregando” muitas vezes não efet...
# 3                 Kilmeer  Após atualização o APP não está abrindo no iPh...
# 4            GiovanniPolo  está dando mensagem dizendo que horário do cel...
# ...                   ...                                                ...
# 10116             RaRaull  Cadastrei a senha eletrônica com 6 dígitos. Ag...
# 10117        Alan Moreira  App “ok”, muitos bugs e plataforma pouco intui...
# 10118             Rtunoda  Não funciona com 3g, só wifi. E não permite au...
# 10119              Edu.05                              Precisa melhorar tudo
# 10120           Ed_Alemao  Após a ultima atualização o aplicativo nao ent...
#
#        score                                           resposta  \
# 0          5  Boa tarde! O que está acontecendo? Por gentile...
# 1          5  Bom dia! Gostaríamos de analisar essa situação...
# 2          1  Bom dia! Por gentileza, envie mais informações...
# 3          1  Boa tarde! Estamos trabalhando para que os dev...
# 4          1  Boa tarde, Giovanni! Vamos verificar o que est...
# ...      ...                                                ...
# 10116      1  Oi, Raul. Você conseguiu atualizar a senha e u...
# 10117      3                                                NaN
# 10118      1  Olá. Disponibilizamos uma atualização do aplic...
# 10119      1  Oi, Edu. Disponibilizamos uma atualização do a...
# 10120      1  Oi, Ed. Disponibilizamos uma atualização do ap...
#
#                      data              app_name        store
# 0     2020-03-13 22:08:36  Bradesco Net Empresa  Apple Store
# 1     2020-11-16 12:03:34  Bradesco Net Empresa  Apple Store
# 2     2020-11-18 11:52:15  Bradesco Net Empresa  Apple Store
# 3     2020-03-14 00:25:42  Bradesco Net Empresa  Apple Store
# 4     2019-03-14 20:09:39  Bradesco Net Empresa  Apple Store
# ...                   ...                   ...          ...
# 10116 2018-07-04 17:05:03        Safra Empresas  Apple Store
# 10117 2025-03-10 21:58:29        Safra Empresas  Apple Store
# 10118 2012-05-26 16:45:17        Safra Empresas  Apple Store
# 10119 2018-10-26 15:03:49        Safra Empresas  Apple Store
# 10120 2013-07-24 09:56:50        Safra Empresas  Apple Store
#
# [10121 rows x 7 columns]

# %%
df_reviews_apple_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10121 entries, 0 to 10120
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user      10121 non-null  object
#  1   review    10121 non-null  object
#  2   score     10121 non-null  int64
#  3   resposta  7435 non-null   object
#  4   data      10121 non-null  datetime64[ns]
#  5   app_name  10121 non-null  object
#  6   store     10121 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 553.6+ KB

# %%
df_reviews_google_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107878 entries, 0 to 107877
# Data columns (total 7 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   user      107878 non-null  object
#  1   review    107854 non-null  object
#  2   score     107878 non-null  int64
#  3   resposta  58964 non-null   object
#  4   data      107878 non-null  datetime64[ns]
#  5   app_name  107878 non-null  object
#  6   store     107878 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 5.8+ MB

# %%
# Concatenando os datasets
df_reviews_final = pd.concat([df_reviews_google_final, df_reviews_apple_final], ignore_index=True)

# %%
df_reviews_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117999 entries, 0 to 117998
# Data columns (total 7 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   user      117999 non-null  object
#  1   review    117975 non-null  object
#  2   score     117999 non-null  int64
#  3   resposta  66399 non-null   object
#  4   data      117999 non-null  datetime64[ns]
#  5   app_name  117999 non-null  object
#  6   store     117999 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 6.3+ MB

# %%
df_reviews_final.to_csv('df_reviews_final.csv', index=False, encoding='utf-8-sig')

print("Arquivo CSV salvo com sucesso!")
# Out:
# Arquivo CSV salvo com sucesso!

# %%
df_reviews_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117999 entries, 0 to 117998
# Data columns (total 7 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   user      117999 non-null  object
#  1   review    117975 non-null  object
#  2   score     117999 non-null  int64
#  3   resposta  66399 non-null   object
#  4   data      117999 non-null  datetime64[ns]
#  5   app_name  117999 non-null  object
#  6   store     117999 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 6.3+ MB

# %%
# file_path = "dataset.xlsx"
df_reviews_final.to_excel('df_reviews_final.xlsx', index=False)
